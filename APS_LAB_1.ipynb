# %% [markdown]
# 1.A fair coin is tossed 100 times.Calculate:
# •	Number of heads
# •	Number of tails
# •	Experimental probability of Head
# •	Experimental probability of Tai

# %%
import random

n = 100

# Toss the coin 100 times
tosses = [random.choice(["Head", "Tail"]) for _ in range(n)]

# Count heads and tails
heads = tosses.count("Head")
tails = tosses.count("Tail")

# Calculating probability
probability_head = heads / n
probability_tail = tails / n

print("Number of Heads:", heads)
print("Number of Tails:", tails)

print("Experimental Probability of Head:", probability_head)
print("Experimental Probability of Tail:", probability_tail)
# Out:
# Number of Heads: 46
# Number of Tails: 54
# Experimental Probability of Head: 0.46
# Experimental Probability of Tail: 0.54

# %% [markdown]
# 2. check Effect of the number of trials
# Repeat the coin-toss experiment for: n=10, 100, 1,000, 10,000

# %%
import random

trial_values = [10, 100, 1000, 10000]

print("Fair Coin Toss Experiment for Different Number of Trials\n")

for n in trial_values:  #loop is for every trail values

    tosses = [random.choice(["Head", "Tail"]) for _ in range(n)]

    # Count heads and tails
    heads = tosses.count("Head")
    tails = tosses.count("Tail")

    # Calculating probability
    probability_head = heads / n
    probability_tail = tails / n

    print(f"\nNumber of Trials: {n}")
    print("Number of Heads:", heads)
    print("Number of Tails:", tails)

    print("Experimental Probability of Head:", probability_head)
    print("Experimental Probability of Tail:", probability_tail)
# Out:
# Fair Coin Toss Experiment for Different Number of Trials
#
#
# Number of Trials: 10
# Number of Heads: 4
# Number of Tails: 6
# Experimental Probability of Head: 0.4
# Experimental Probability of Tail: 0.6
#
# Number of Trials: 100
# Number of Heads: 41
# Number of Tails: 59
# Experimental Probability of Head: 0.41
# Experimental Probability of Tail: 0.59
#
# Number of Trials: 1000
# Number of Heads: 515
# Number of Tails: 485
# Experimental Probability of Head: 0.515
# Experimental Probability of Tail: 0.485
#
# Number of Trials: 10000
# Number of Heads: 5065
# Number of Tails: 4935
# Experimental Probability of Head: 0.5065
# Experimental Probability of Tail: 0.4935

# %% [markdown]
# 3. Rolling a die: A fair die is rolled 6,000 times.
# Calculate the experimental probability of each outcome: S={1,2,3,4,5,6}

# %%
import random

n = 6000

# Roll die 6000 times
rolls = [random.randint(1, 6) for _ in range(n)]

print("DIE ROLLING EXPERIMENT FOR 6000 TRIALS\n")

# this loop is for Checking each die outcome
for outcome in range(1, 7):

    # Count how many times it occurred
    frequency = rolls.count(outcome)

    # probability
    probability = frequency / n

    print(f"Outcome {outcome}")
    print(f"Frequency: {frequency}")
    print(f"Probability: {probability}\n")
# Out:
# DIE ROLLING EXPERIMENT FOR 6000 TRIALS
#
# Outcome 1
# Frequency: 991
# Probability: 0.16516666666666666
#
# Outcome 2
# Frequency: 957
# Probability: 0.1595
#
# Outcome 3
# Frequency: 994
# Probability: 0.16566666666666666
#
# Outcome 4
# Frequency: 1034
# Probability: 0.17233333333333334
#
# Outcome 5
# Frequency: 1040
# Probability: 0.17333333333333334
#
# Outcome 6
# Frequency: 984
# Probability: 0.164

# %% [markdown]
# 4.Addition rule for disjoint events
# A die is rolled 10,000 times.
# Define: A=getting 1, B= getting 6, check the events are joint or disjoint
# Verify: P(A∪B)=P(A)+P(B)

# %%
import random

n = 10000

# Roll die 10000 times
rolls = [random.randint(1, 6) for _ in range(n)]

# Count 1s and 6s
count_A = rolls.count(1)
count_B = rolls.count(6)

# A union B means getting 1 or 6
A_union_B = count_A + count_B

# probability
probability_A = count_A / n
probability_B = count_B / n
probability_A_union_B = A_union_B / n

print("ADDITION RULE FOR DISJOINT SETS\n")

print("Number of 1s:", count_A)
print("Number of 6s:", count_B)

print("Probability of getting 1:", probability_A)
print("Probability of getting 6:", probability_B)

print("P(A ∪ B) =", probability_A_union_B)
print("P(A) + P(B) =", probability_A + probability_B)

# Verifying addition rule
print("P(A ∪ B) = P(A) + P(B):",
      probability_A_union_B == (probability_A + probability_B))
# Out:
# ADDITION RULE FOR DISJOINT SETS
#
# Number of 1s: 1694
# Number of 6s: 1686
# Probability of getting 1: 0.1694
# Probability of getting 6: 0.1686
# P(A ∪ B) = 0.338
# P(A) + P(B) = 0.33799999999999997
# P(A ∪ B) = P(A) + P(B): False

# %% [markdown]
# 5.	Addition rule for overlapping events
# For one die roll, define: A=getting an even number A={2,4,6} and B=getting a number greater than 3 B={4,5,6}
# Verify: P(A∪B)=P(A)+P(B)−P(A∩B)

# %%
# Define the events since it is a single trail no need to use random
A = {2, 4, 6}
B = {4, 5, 6}

# Find common elements in both event
intersection = A & B

# Find all elements
union = A | B

# finding probability
P_A = len(A) / 6
P_B = len(B) / 6
P_intersection = len(intersection) / 6
P_union = len(union) / 6

print("ADDITION RULE FOR OVERLAPPING EVENTS\n")

print("A intersection B =", intersection)
print("A union B =", union)

print("P(A) =", P_A)
print("P(B) =", P_B)
print("P(A intersection B) =", P_intersection)
print("P(A union B) =", P_union)

# joint probability rule
print("P(A) + P(B) - P(A intersection B) =",
      P_A + P_B - P_intersection)
# Out:
# ADDITION RULE FOR OVERLAPPING EVENTS
#
# A intersection B = {4, 6}
# A union B = {2, 4, 5, 6}
# P(A) = 0.5
# P(B) = 0.5
# P(A intersection B) = 0.3333333333333333
# P(A union B) = 0.6666666666666666
# P(A) + P(B) - P(A intersection B) = 0.6666666666666667

# %% [markdown]
# 6.	Multiplication rule for independent events
# A coin is tossed and a die is rolled 10,000 times.
# Define:
# •	obtaining Head
# •	obtaining an even number
# Verify: P(A∩B)=P(A)P(B)

# %%
import random

n = 10000

heads = 0
even = 0
both = 0

# Toss coin and roll die using random function
for _ in range(n):

    coin = random.choice(["Head", "Tail"])
    die = random.randint(1, 6)

    # Count Heads
    if coin == "Head":
        heads += 1

    # Count even numbers
    if die % 2 == 0:
        even += 1

    # Count Head and even together
    if coin == "Head" and die % 2 == 0:
        both += 1

P_A = heads / n
P_B = even / n
P_A_and_B = both / n

print("MULTIPLICATION RULE FOR INDEPENDENT EVENTS\n")

print("Number of Heads:", heads)
print("Number of Even Rolls:", even)
print("Number of Head and Even:", both)

print("\nP(A ∩ B) =", P_A_and_B)
print("P(A) × P(B) =", P_A * P_B)
# Out:
# MULTIPLICATION RULE FOR INDEPENDENT EVENTS
#
# Number of Heads: 4993
# Number of Even Rolls: 5012
# Number of Head and Even: 2525
#
# P(A ∩ B) = 0.2525
# P(A) × P(B) = 0.25024916
